# %% [markdown]
# # Description
#
# In this notebook, we test generation of empirical bench data.

# %%
from empirical_bench_data.empirical_bench import load, gen_dataset

data = load()

keys = [p["key"] for p in data["problems"].values()]
keys
# Out:
# ['hubble',
#  'kepler',
#  'newton',
#  'planck',
#  'tully',
#  'leavitt',
#  'schechter',
#  'bode',
#  'ideal_gas',
#  'rydberg']

# %%
X, y = gen_dataset(data, "rydberg", scale_dataset=True)
print(X.shape)
print(y.shape)
# Out:
# (50, 2)
# (50,)
