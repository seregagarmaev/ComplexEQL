# %% [markdown]
# # Description
#
# We evaluate the scalability of CEQL on the previously generated data with growing number of input variables.

# %%
# ceql_scalability_experiment_poly2.py

from __future__ import annotations

import csv
import time
from pathlib import Path
from typing import Any, Dict, List, Tuple

import h5py
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

from config.scalability_config import DataCFG, OperonCFG, CEQL_TRAIN, CEQL
from src.ComplexEQL import ComplexEQL
from src.utils import set_seed, train


def mse(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    y_true = np.asarray(y_true, dtype=np.float64).reshape(-1)
    y_pred = np.asarray(y_pred, dtype=np.float64).reshape(-1)
    return float(np.mean((y_true - y_pred) ** 2))


def _make_seeds() -> Tuple[int, ...]:
    n = int(getattr(OperonCFG, "runs_per_d", 5))
    cfg_seeds = tuple(getattr(OperonCFG, "seeds", ()))
    if len(cfg_seeds) >= n:
        return cfg_seeds[:n]
    return tuple(range(n))


def _print_run_header(Expression: str, d: int, seed: int, run_j: int, n_runs: int, Xtr: np.ndarray, Xte: np.ndarray) -> None:
    print("\n" + "=" * 110)
    print(f"RUN START | Expression={Expression} | d={d} | run={run_j+1}/{n_runs} | seed={seed}")
    print(f"  X_train: {Xtr.shape} | X_test: {Xte.shape}")
    print(
        "  ceql_cfg: "
        f"device={getattr(CEQL_TRAIN,'device','cpu')}, "
        f"batch={int(getattr(CEQL_TRAIN,'train_batch_size',2**14))}, "
        f"lr={float(getattr(CEQL_TRAIN,'lr',1e-3))}, "
        f"phases=[{int(getattr(CEQL_TRAIN,'phase1_epochs',0))},"
        f"{int(getattr(CEQL_TRAIN,'phase2_epochs',0))},"
        f"{int(getattr(CEQL_TRAIN,'phase3_epochs',0))}], "
        f"l1=[{float(getattr(CEQL_TRAIN,'l1_reg_coeff_phase1',0.0))},"
        f"{float(getattr(CEQL_TRAIN,'l1_reg_coeff_phase2',0.0))},"
        f"{float(getattr(CEQL_TRAIN,'l1_reg_coeff_phase3',0.0))}], "
        f"imag=[{float(getattr(CEQL_TRAIN,'imag_w_coeff_phase1',0.0))},"
        f"{float(getattr(CEQL_TRAIN,'imag_w_coeff_phase2',0.0))},"
        f"{float(getattr(CEQL_TRAIN,'imag_w_coeff_phase3',0.0))}]"
    )
    print("=" * 110)


def _aggregate(rows: List[Dict[str, Any]], Expression: str, d_list: List[int]) -> Dict[int, Dict[str, float]]:
    out: Dict[int, Dict[str, float]] = {}
    for d in d_list:
        sub = [r for r in rows if r["Expression"] == Expression and r["d"] == d]
        tr = np.array([r["train_mse"] for r in sub], dtype=np.float64)
        te = np.array([r["test_mse"] for r in sub], dtype=np.float64)
        out[d] = {
            "train_mean": float(tr.mean()),
            "train_std": float(tr.std(ddof=0)),
            "test_mean": float(te.mean()),
            "test_std": float(te.std(ddof=0)),
        }
    return out


def _plot_errorbars_uniform_x(Expression: str, agg: Dict[int, Dict[str, float]], d_list: List[int]) -> None:
    x_pos = np.arange(len(d_list), dtype=np.int32)

    tr_mean = np.array([agg[d]["train_mean"] for d in d_list], dtype=np.float64)
    tr_std = np.array([agg[d]["train_std"] for d in d_list], dtype=np.float64)
    te_mean = np.array([agg[d]["test_mean"] for d in d_list], dtype=np.float64)
    te_std = np.array([agg[d]["test_std"] for d in d_list], dtype=np.float64)

    plt.figure()
    plt.errorbar(x_pos, tr_mean, yerr=tr_std, fmt="-o", capsize=4, label="Train MSE (mean ± std)")
    plt.errorbar(x_pos, te_mean, yerr=te_std, fmt="-o", capsize=4, label="Test MSE (mean ± std)")

    if getattr(OperonCFG, "y_log_scale", True):
        plt.yscale("log")

    plt.xlabel(getattr(OperonCFG, "x_label", "Number of Input Variables"))
    plt.ylabel(getattr(OperonCFG, "y_label", "MSE"))
    plt.title(f"CEQL scalability | Expression={Expression} | {len(d_list)} d-values")

    plt.xticks(x_pos, [str(d) for d in d_list])
    plt.legend()
    plt.tight_layout()
    plt.show()


def _write_report_csv(rows: List[Dict[str, Any]], path: Path) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)

    fieldnames = [
        "Expression",
        "d",
        "run",
        "seed",
        "train_mse",
        "test_mse",
        "expr",
    ]

    with path.open("w", newline="", encoding="utf-8") as fp:
        w = csv.DictWriter(fp, fieldnames=fieldnames)
        w.writeheader()
        for r in rows:
            w.writerow({k: r.get(k, "") for k in fieldnames})

    print(f"Saved per-run report: {str(path)}")


def _build_scheduler(optimizer: torch.optim.Optimizer):
    if getattr(CEQL_TRAIN, "scheduler", None) == "ReduceLROnPlateau":
        return torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer, **getattr(CEQL_TRAIN, "schedulerparams", {})
        )
    if getattr(CEQL_TRAIN, "scheduler", None) is None:
        return None
    raise ValueError(f"Unknown scheduler: {getattr(CEQL_TRAIN,'scheduler',None)!r}")


def _safe_symbolic_expr(model: ComplexEQL, d: int) -> str:
    try:
        syms = [sp.Symbol(f"X{i+1}") for i in range(d)]
        expr = model.get_symbolic_expression(
            syms,
            rounding_decimals=int(getattr(OperonCFG, "sym_decimals", 15)),
            use_imag=False,
        )
        if expr is None:
            return ""
        return str(expr)
    except Exception:
        return ""


def main() -> None:
    t0_all = time.perf_counter()
    rows: List[Dict[str, Any]] = []

    h5_path = str(DataCFG.out_path)

    Expressions_cfg: Tuple[str, ...] = tuple(getattr(OperonCFG, "kinds", ()))
    if len(Expressions_cfg) == 0:
        Expressions = ("P2",)
    else:
        Expressions = tuple("P2" if e == "P3" else e for e in Expressions_cfg)

    seeds = _make_seeds()
    n_runs = len(seeds)

    p = Path(getattr(CEQL_TRAIN, "report_csv_path", "reports/ceql_scalability.csv"))
    report_csv_path = p.with_name(p.stem + "_poly2" + p.suffix)

    device_str = str(getattr(CEQL_TRAIN, "device", "cpu"))
    device = torch.device(device_str)

    print(f"Opening HDF5: {h5_path}")
    with h5py.File(h5_path, "r") as f:
        d_list = list(map(int, f.attrs["d_list"]))
        print(f"d_list = {d_list}")
        print(f"Expressions = {list(Expressions)}")
        print(f"seeds (runs) = {list(seeds)} (runs_per_d={n_runs})")
        print(f"device = {device_str}")
        print(f"report_csv_path = {report_csv_path}")

        for Expression in Expressions:
            print(f"\n===== Expression: {Expression} =====")
            for d in d_list:
                print(f"Loading data for Expression={Expression}, d={d} ...")

                Xtr = f[f"data/{Expression}/d{d}/train/X"][...].astype(np.float32, copy=False)
                ytr = f[f"data/{Expression}/d{d}/train/y"][...].astype(np.float32, copy=False).reshape(-1)

                Xte = f[f"data/{Expression}/d{d}/test/X"][...].astype(np.float32, copy=False)
                yte = f[f"data/{Expression}/d{d}/test/y"][...].astype(np.float32, copy=False).reshape(-1)

                print(f"Loaded: Xtr={Xtr.shape}, ytr={ytr.shape}, Xte={Xte.shape}, yte={yte.shape}")

                for run_j, seed in enumerate(seeds):
                    _print_run_header(Expression, d, seed, run_j, n_runs, Xtr, Xte)

                    set_seed(int(seed))

                    CEQL.n_input_fields = int(d)

                    Xtr_t = torch.tensor(Xtr, device=device)
                    ytr_t = torch.tensor(ytr.reshape(-1, 1), device=device)

                    dataset = TensorDataset(Xtr_t, ytr_t)
                    dataloader = DataLoader(
                        dataset,
                        batch_size=int(getattr(CEQL_TRAIN, "train_batch_size", 2**14)),
                        shuffle=True,
                        drop_last=False,
                    )

                    model = ComplexEQL(CEQL).to(device)
                    loss_fn = nn.MSELoss()
                    optimizer = torch.optim.Adam(model.parameters(), lr=float(getattr(CEQL_TRAIN, "lr", 1e-3)))
                    scheduler = _build_scheduler(optimizer)

                    print("train() started ...")
                    model, _loss_traces = train(
                        model=model,
                        dataloader=dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        cfg=CEQL_TRAIN,
                        device=device,
                        scheduler=scheduler,
                    )
                    print("train() finished")

                    model.eval()
                    with torch.no_grad():
                        yhat_tr = model(Xtr_t).real.squeeze(-1).detach().cpu().numpy().astype(np.float64, copy=False)

                        Xte_t = torch.tensor(Xte, device=device)
                        yhat_te = model(Xte_t).real.squeeze(-1).detach().cpu().numpy().astype(np.float64, copy=False)

                    tr_mse = mse(ytr.astype(np.float64, copy=False), yhat_tr)
                    te_mse = mse(yte.astype(np.float64, copy=False), yhat_te)

                    expr_str = _safe_symbolic_expr(model, d=d)
                    if expr_str:
                        print("expr_str:", expr_str)

                    rows.append(
                        {
                            "Expression": Expression,
                            "d": int(d),
                            "run": int(run_j),
                            "seed": int(seed),
                            "train_mse": float(tr_mse),
                            "test_mse": float(te_mse),
                            "expr": expr_str,
                        }
                    )

                    print(
                        f"RESULT | Expression={Expression} | d={d:>3} | run={run_j+1}/{n_runs} | seed={seed} | "
                        f"train_mse={tr_mse:.6e} | test_mse={te_mse:.6e}"
                    )

    _write_report_csv(rows, report_csv_path)

    print("\n=== Summary (mean±std over runs) ===")
    for Expression in Expressions:
        d_list_sorted = sorted({r["d"] for r in rows if r["Expression"] == Expression})
        agg = _aggregate(rows, Expression=Expression, d_list=d_list_sorted)
        for d in d_list_sorted:
            a = agg[d]
            print(
                f"Expression={Expression} d={d:>3} | "
                f"train_mse={a['train_mean']:.6e}±{a['train_std']:.6e} | "
                f"test_mse={a['test_mean']:.6e}±{a['test_std']:.6e}"
            )
        _plot_errorbars_uniform_x(Expression=Expression, agg=agg, d_list=d_list_sorted)

    total_s = time.perf_counter() - t0_all
    print(f"\nAll done in {total_s:.2f} s")


if __name__ == "__main__":
    main()
# Out:
# Opening HDF5: scalability_experiment_data.h5
# d_list = [2, 4, 8, 16, 32, 64]
# Expressions = ['P2']
# seeds (runs) = [0, 1, 2, 3, 4] (runs_per_d=5)
# device = cpu
# report_csv_path = reports/ceql_scalability_poly2.csv
#
# ===== Expression: P2 =====
# Loading data for Expression=P2, d=2 ...
# Loaded: Xtr=(1000, 2), ytr=(1000,), Xte=(1000, 2), yte=(1000,)
#
# ==============================================================================================================
# RUN START | Expression=P2 | d=2 | run=1/5 | seed=0
#   X_train: (1000, 2) | X_test: (1000, 2)
#   ceql_cfg: device=cpu, batch=16384, lr=0.001, phases=[20000,30000,20000], l1=[0.001,0.001,1e-07], imag=[10.0,10.0,0.001]
# ==============================================================================================================
# Random seed set as 0
# train() started ...
# [PHASE1 | Epoch 1] lr=1.00e-03, total=6.6356e+02, data=5.8314e+02, sparsity_reg=2.8587e-02, imag_w=8.0384e+01, active_edges=106
# [PHASE1 | Epoch 100] lr=1.00e-03, total=5.3397e+02, data=4.9035e+02, sparsity_reg=2.6859e-02, imag_w=4.3591e+01, active_edges=106
# [PHASE1 | Epoch 200] lr=1.00e-03, total=6.6274e+01, data=4.3573e+01, sparsity_reg=2.9932e-02, imag_w=2.2672e+01, active_edges=106
# [PHASE1 | Epoch 300] lr=1.00e-03, total=2.9842e+01, data=1.8606e+01, sparsity_reg=2.8269e-02, imag_w=1.1208e+01, active_edges=106
# [PHASE1 | Epoch 400] lr=1.00e-03, total=1.9907e+01, data=1.4663e+01, sparsity_reg=2.7762e-02, imag_w=5.2163e+00, active_edges=106
# [PHASE1 | Epoch 500] lr=1.00e-03, total=1.4304e+01, data=1.2010e+01, sparsity_reg=2.7832e-02, imag_w=2.2662e+00, active_edges=106
# [PHASE1 | Epoch 600] lr=1.00e-03, total=1.0805e+01, data=9.8645e+00, sparsity_reg=2.8161e-02, imag_w=9.1270e-01, active_edges=106
# [PHASE1 | Epoch 700] lr=1.00e-03, total=8.6389e+00, data=8.2716e+00, sparsity_reg=2.8539e-02, imag_w=3.3883e-01, active_edges=106
# [PHASE1 | Epoch 800] lr=1.00e-03, total=7.3225e+00, data=7.1782e+00, sparsity_reg=2.8906e-02, imag_w=1.1539e-01, active_edges=106
# [PHASE1 | Epoch 900] lr=1.00e-03, total=6.5134e+00, data=6.4483e+00, sparsity_reg=2.9163e-02, imag_w=3.5905e-02, active_edges=106
# [PHASE1 | Epoch 1000] lr=1.00e-03, total=5.9665e+00, data=5.9271e+00, sparsity_reg=2.9302e-02, imag_w=1.0166e-02, active_edges=106
# [PHASE1 | Epoch 1100] lr=1.00e-03, total=5.5283e+00, data=5.4963e+00, sparsity_reg=2.9386e-02, imag_w=2.6075e-03, active_edges=106
# [PHASE1 | Epoch 1200] lr=1.00e-03, total=5.1210e+00, data=5.0910e+00, sparsity_reg=2.9409e-02, imag_w=6.0222e-04, active_edges=106
# [PHASE1 | Epoch 1300] lr=1.00e-03, total=4.7141e+00, data=4.6846e+00, sparsity_reg=2.9410e-02, imag_w=1.2388e-04, active_edges=106
# [PHASE1 | Epoch 1400] lr=1.00e-03, total=4.3001e+00, data=4.2706e+00, sparsity_reg=2.9470e-02, imag_w=2.2323e-05, active_edges=106
# [PHASE1 | Epoch 1500] lr=1.00e-03, total=3.8805e+00, data=3.8510e+00, sparsity_reg=2.9507e-02, imag_w=3.4046e-06, active_edges=106
# [PHASE1 | Epoch 1600] lr=1.00e-03, total=3.4606e+00, data=3.4311e+00, sparsity_reg=2.9522e-02, imag_w=4.3464e-07, active_edges=106
# [PHASE1 | Epoch 1700] lr=1.00e-03, total=3.0476e+00, data=3.0179e+00, sparsity_reg=2.9693e-02, imag_w=4.7226e-08, active_edges=106
# [PHASE1 | Epoch 1800] lr=1.00e-03, total=2.6487e+00, data=2.6187e+00, sparsity_reg=2.9975e-02, imag_w=4.7628e-09, active_edges=106
# [PHASE1 | Epoch 1900] lr=1.00e-03, total=2.2706e+00, data=2.2403e+00, sparsity_reg=3.0314e-02, imag_w=4.3874e-10, active_edges=106
# [PHASE1 | Epoch 2000] lr=1.00e-03, total=1.9191e+00, data=1.8884e+00, sparsity_reg=3.0650e-02, imag_w=3.5028e-11, active_edges=106
# [PHASE1 | Epoch 2100] lr=1.00e-03, total=1.5988e+00, data=1.5679e+00, sparsity_reg=3.0981e-02, imag_w=2.3926e-12, active_edges=106
# [PHASE1 | Epoch 2200] lr=1.00e-03, total=1.3130e+00, data=1.2817e+00, sparsity_reg=3.1285e-02, imag_w=1.3743e-13, active_edges=106
# [PHASE1 | Epoch 2300] lr=1.00e-03, total=1.0632e+00, data=1.0316e+00, sparsity_reg=3.1577e-02, imag_w=6.5214e-15, active_edges=106
# [PHASE1 | Epoch 2400] lr=1.00e-03, total=8.4955e-01, data=8.1770e-01, sparsity_reg=3.1850e-02, imag_w=2.5292e-16, active_edges=106
# [PHASE1 | Epoch 2500] lr=1.00e-03, total=6.7065e-01, data=6.3856e-01, sparsity_reg=3.2092e-02, imag_w=7.8725e-18, active_edges=106
# [PHASE1 | Epoch 2600] lr=1.00e-03, total=5.2403e-01, data=4.9171e-01, sparsity_reg=3.2320e-02, imag_w=1.9307e-19, active_edges=106
# [PHASE1 | Epoch 2700] lr=1.00e-03, total=4.0633e-01, data=3.7379e-01, sparsity_reg=3.2541e-02, imag_w=3.6539e-21, active_edges=106
# [PHASE1 | Epoch 2800] lr=1.00e-03, total=3.1364e-01, data=2.8090e-01, sparsity_reg=3.2733e-02, imag_w=5.2090e-23, active_edges=106
# [PHASE1 | Epoch 2900] lr=1.00e-03, total=2.4194e-01, data=2.0905e-01, sparsity_reg=3.2897e-02, imag_w=5.4388e-25, active_edges=106
# [PHASE1 | Epoch 7200] lr=1.00e-03, total=3.4385e-02, data=1.4292e-03, sparsity_reg=3.2956e-02, imag_w=2.6976e-08, active_edges=106
# [PHASE1 | Epoch 7300] lr=1.00e-03, total=3.4259e-02, data=1.3545e-03, sparsity_reg=3.2904e-02, imag_w=1.7868e-08, active_edges=106
# [PHASE1 | Epoch 7400] lr=1.00e-03, total=3.4133e-02, data=1.2824e-03, sparsity_reg=3.2850e-02, imag_w=1.4180e-08, active_edges=106
# [PHASE1 | Epoch 7500] lr=1.00e-03, total=3.4006e-02, data=1.2131e-03, sparsity_reg=3.2793e-02, imag_w=1.2160e-08, active_edges=106
# [PHASE1 | Epoch 7600] lr=1.00e-03, total=3.3882e-02, data=1.1465e-03, sparsity_reg=3.2736e-02, imag_w=1.1721e-08, active_edges=106
# [PHASE1 | Epoch 7700] lr=1.00e-03, total=3.3758e-02, data=1.0834e-03, sparsity_reg=3.2674e-02, imag_w=1.3559e-08, active_edges=106
# [PHASE1 | Epoch 7800] lr=1.00e-03, total=3.3633e-02, data=1.0228e-03, sparsity_reg=3.2610e-02, imag_w=1.6616e-08, active_edges=106
# [PHASE1 | Epoch 7900] lr=1.00e-03, total=3.3508e-02, data=9.6441e-04, sparsity_reg=3.2544e-02, imag_w=1.5317e-08, active_edges=106
# [PHASE1 | Epoch 8000] lr=1.00e-03, total=3.3383e-02, data=9.0830e-04, sparsity_reg=3.2474e-02, imag_w=6.6091e-09, active_edges=106
# [PHASE1 | Epoch 8100] lr=1.00e-03, total=3.3256e-02, data=8.5441e-04, sparsity_reg=3.2402e-02, imag_w=1.7975e-08, active_edges=106
# [PHASE1 | Epoch 8200] lr=1.00e-03, total=3.3129e-02, data=8.0270e-04, sparsity_reg=3.2326e-02, imag_w=2.0944e-08, active_edges=106
# [PHASE1 | Epoch 8300] lr=1.00e-03, total=3.3001e-02, data=7.5314e-04, sparsity_reg=3.2248e-02, imag_w=9.4625e-09, active_edges=106
# [PHASE1 | Epoch 8400] lr=1.00e-03, total=3.2871e-02, data=7.0565e-04, sparsity_reg=3.2166e-02, imag_w=1.9327e-08, active_edges=106
# [PHASE1 | Epoch 8500] lr=1.00e-03, total=3.2745e-02, data=6.6225e-04, sparsity_reg=3.2083e-02, imag_w=1.3020e-08, active_edges=106
# [PHASE1 | Epoch 8600] lr=1.00e-03, total=3.2620e-02, data=6.2228e-04, sparsity_reg=3.1998e-02, imag_w=2.5536e-08, active_edges=106
# [PHASE1 | Epoch 8700] lr=1.00e-03, total=3.2494e-02, data=5.8379e-04, sparsity_reg=3.1910e-02, imag_w=2.3628e-08, active_edges=106
# [PHASE1 | Epoch 8800] lr=1.00e-03, total=3.2366e-02, data=5.4694e-04, sparsity_reg=3.1819e-02, imag_w=1.7997e-08, active_edges=106
# [PHASE1 | Epoch 8900] lr=1.00e-03, total=3.2235e-02, data=5.1167e-04, sparsity_reg=3.1723e-02, imag_w=1.9029e-08, active_edges=106
# [PHASE1 | Epoch 9000] lr=1.00e-03, total=3.2101e-02, data=4.7803e-04, sparsity_reg=3.1623e-02, imag_w=7.1439e-09, active_edges=106
# [PHASE1 | Epoch 9100] lr=1.00e-03, total=3.1965e-02, data=4.4594e-04, sparsity_reg=3.1519e-02, imag_w=1.7399e-08, active_edges=106
# [PHASE1 | Epoch 9200] lr=1.00e-03, total=3.1826e-02, data=4.1537e-04, sparsity_reg=3.1411e-02, imag_w=1.2558e-08, active_edges=106
# [PHASE1 | Epoch 9300] lr=1.00e-03, total=3.1683e-02, data=3.8629e-04, sparsity_reg=3.1297e-02, imag_w=1.0140e-08, active_edges=106
# [PHASE1 | Epoch 9400] lr=1.00e-03, total=3.1537e-02, data=3.5866e-04, sparsity_reg=3.1179e-02, imag_w=1.5609e-08, active_edges=106
# [PHASE1 | Epoch 9500] lr=1.00e-03, total=3.1387e-02, data=3.3243e-04, sparsity_reg=3.1055e-02, imag_w=2.3575e-08, active_edges=106
# [PHASE1 | Epoch 9600] lr=1.00e-03, total=3.1233e-02, data=3.0760e-04, sparsity_reg=3.0925e-02, imag_w=2.3510e-08, active_edges=106
# [PHASE1 | Epoch 9700] lr=1.00e-03, total=3.1074e-02, data=2.8410e-04, sparsity_reg=3.0790e-02, imag_w=1.7418e-08, active_edges=106
# [PHASE1 | Epoch 9800] lr=1.00e-03, total=3.0913e-02, data=2.6202e-04, sparsity_reg=3.0651e-02, imag_w=1.4079e-08, active_edges=106
# [PHASE1 | Epoch 9900] lr=1.00e-03, total=3.0747e-02, data=2.4107e-04, sparsity_reg=3.0506e-02, imag_w=1.7927e-08, active_edges=106
# [PHASE1 | Epoch 10000] lr=1.00e-03, total=3.0575e-02, data=2.2133e-04, sparsity_reg=3.0354e-02, imag_w=2.3202e-08, active_edges=106
# [PHASE1 | Epoch 10100] lr=1.00e-03, total=3.0398e-02, data=2.0276e-04, sparsity_reg=3.0195e-02, imag_w=2.6989e-08, active_edges=106
# [PHASE1 | Epoch 10200] lr=1.00e-03, total=3.0215e-02, data=1.8531e-04, sparsity_reg=3.0029e-02, imag_w=3.1383e-08, active_edges=106
# [PHASE1 | Epoch 10300] lr=1.00e-03, total=3.0025e-02, data=1.6894e-04, sparsity_reg=2.9856e-02, imag_w=1.9356e-08, active_edges=106
# [PHASE1 | Epoch 10400] lr=1.00e-03, total=2.9829e-02, data=1.5361e-04, sparsity_reg=2.9675e-02, imag_w=2.4828e-08, active_edges=106
# [PHASE1 | Epoch 10500] lr=1.00e-03, total=2.9625e-02, data=1.3928e-04, sparsity_reg=2.9486e-02, imag_w=3.0989e-08, active_edges=106
# [PHASE1 | Epoch 10600] lr=1.00e-03, total=2.9418e-02, data=1.2600e-04, sparsity_reg=2.9292e-02, imag_w=3.2708e-08, active_edges=106
# [PHASE1 | Epoch 10700] lr=1.00e-03, total=2.9209e-02, data=1.1348e-04, sparsity_reg=2.9096e-02, imag_w=2.2854e-08, active_edges=106
# [PHASE1 | Epoch 10800] lr=1.00e-03, total=2.9019e-02, data=1.2713e-04, sparsity_reg=2.8892e-02, imag_w=2.1860e-08, active_edges=106
# [PHASE1 | Epoch 14500] lr=1.00e-03, total=1.9366e-02, data=7.4967e-05, sparsity_reg=1.9290e-02, imag_w=7.4061e-07, active_edges=106
# [PHASE1 | Epoch 14600] lr=1.00e-03, total=1.9097e-02, data=5.1896e-06, sparsity_reg=1.9089e-02, imag_w=2.2905e-06, active_edges=106
# [PHASE1 | Epoch 14700] lr=1.00e-03, total=1.8903e-02, data=2.7380e-06, sparsity_reg=1.8899e-02, imag_w=7.8898e-07, active_edges=106
# [PHASE1 | Epoch 14800] lr=1.00e-03, total=1.8731e-02, data=3.5489e-06, sparsity_reg=1.8727e-02, imag_w=8.1269e-07, active_edges=106
# [PHASE1 | Epoch 14900] lr=1.00e-03, total=1.8822e-02, data=2.6161e-04, sparsity_reg=1.8560e-02, imag_w=6.3723e-07, active_edges=106
# [PHASE1 | Epoch 15000] lr=1.00e-03, total=1.8393e-02, data=1.1572e-06, sparsity_reg=1.8391e-02, imag_w=7.4122e-07, active_edges=106
# [PHASE1 | Epoch 15100] lr=1.00e-03, total=1.8340e-02, data=1.1379e-04, sparsity_reg=1.8225e-02, imag_w=9.3729e-07, active_edges=106
# [PHASE1 | Epoch 15200] lr=1.00e-03, total=1.8061e-02, data=1.0682e-06, sparsity_reg=1.8059e-02, imag_w=8.7354e-07, active_edges=106
# [PHASE1 | Epoch 15300] lr=1.00e-03, total=1.7908e-02, data=1.4094e-06, sparsity_reg=1.7905e-02, imag_w=1.0712e-06, active_edges=106
# [PHASE1 | Epoch 15400] lr=1.00e-03, total=1.7753e-02, data=9.5176e-07, sparsity_reg=1.7751e-02, imag_w=1.2321e-06, active_edges=106
# [PHASE1 | Epoch 15500] lr=1.00e-03, total=1.7651e-02, data=8.5898e-07, sparsity_reg=1.7615e-02, imag_w=3.4309e-05, active_edges=106
# [PHASE1 | Epoch 15600] lr=1.00e-03, total=1.7683e-02, data=1.8905e-04, sparsity_reg=1.7493e-02, imag_w=1.2587e-06, active_edges=106
# [PHASE1 | Epoch 15700] lr=1.00e-03, total=1.7374e-02, data=7.2604e-07, sparsity_reg=1.7372e-02, imag_w=1.3809e-06, active_edges=106
# [PHASE1 | Epoch 15800] lr=1.00e-03, total=1.7246e-02, data=2.1273e-06, sparsity_reg=1.7243e-02, imag_w=1.0363e-06, active_edges=106
# [PHASE1 | Epoch 15900] lr=1.00e-03, total=1.7119e-02, data=3.0556e-06, sparsity_reg=1.7115e-02, imag_w=1.1355e-06, active_edges=106
# [PHASE1 | Epoch 16000] lr=1.00e-03, total=1.6992e-02, data=1.9180e-06, sparsity_reg=1.6989e-02, imag_w=1.3487e-06, active_edges=106
# [PHASE1 | Epoch 16100] lr=1.00e-03, total=1.6859e-02, data=7.4610e-07, sparsity_reg=1.6857e-02, imag_w=1.0850e-06, active_edges=106
# [PHASE1 | Epoch 16200] lr=1.00e-03, total=1.6724e-02, data=3.5520e-06, sparsity_reg=1.6719e-02, imag_w=1.0909e-06, active_edges=106
# [PHASE1 | Epoch 16300] lr=1.00e-03, total=1.6584e-02, data=6.2285e-06, sparsity_reg=1.6576e-02, imag_w=1.3996e-06, active_edges=106
# [PHASE1 | Epoch 16400] lr=1.00e-03, total=1.6627e-02, data=1.7204e-04, sparsity_reg=1.6454e-02, imag_w=1.1770e-06, active_edges=106
# [PHASE1 | Epoch 16500] lr=1.00e-03, total=1.6383e-02, data=7.8335e-07, sparsity_reg=1.6367e-02, imag_w=1.4896e-05, active_edges=106
# [PHASE1 | Epoch 16600] lr=1.00e-03, total=1.6289e-02, data=7.3036e-07, sparsity_reg=1.6287e-02, imag_w=1.3537e-06, active_edges=106
# [PHASE1 | Epoch 16700] lr=1.00e-03, total=1.6233e-02, data=2.9359e-05, sparsity_reg=1.6202e-02, imag_w=1.1227e-06, active_edges=106
# [PHASE1 | Epoch 16800] lr=1.00e-03, total=1.6261e-02, data=1.4177e-04, sparsity_reg=1.6118e-02, imag_w=1.2022e-06, active_edges=106
# [PHASE1 | Epoch 16900] lr=1.00e-03, total=1.6154e-02, data=1.2001e-04, sparsity_reg=1.6033e-02, imag_w=1.1760e-06, active_edges=106
# [PHASE1 | Epoch 17000] lr=1.00e-03, total=1.5968e-02, data=1.5062e-05, sparsity_reg=1.5952e-02, imag_w=9.9854e-07, active_edges=106
# [PHASE1 | Epoch 17100] lr=1.00e-03, total=1.5868e-02, data=2.6412e-06, sparsity_reg=1.5864e-02, imag_w=1.2033e-06, active_edges=106
# [PHASE1 | Epoch 17200] lr=1.00e-03, total=1.5819e-02, data=4.4515e-05, sparsity_reg=1.5773e-02, imag_w=9.2814e-07, active_edges=106
# [PHASE1 | Epoch 17300] lr=1.00e-03, total=1.5777e-02, data=9.3448e-05, sparsity_reg=1.5683e-02, imag_w=8.9242e-07, active_edges=106
# [PHASE1 | Epoch 17400] lr=1.00e-03, total=1.5592e-02, data=6.6424e-06, sparsity_reg=1.5584e-02, imag_w=1.0209e-06, active_edges=106
# [PHASE1 | Epoch 17500] lr=1.00e-03, total=1.5510e-02, data=1.0769e-06, sparsity_reg=1.5508e-02, imag_w=9.0746e-07, active_edges=106
# [PHASE1 | Epoch 17600] lr=1.00e-03, total=1.5446e-02, data=1.0403e-06, sparsity_reg=1.5444e-02, imag_w=8.1009e-07, active_edges=106
# [PHASE1 | Epoch 17700] lr=1.00e-03, total=1.5380e-02, data=1.8026e-06, sparsity_reg=1.5377e-02, imag_w=9.4621e-07, active_edges=106
# [PHASE1 | Epoch 17800] lr=1.00e-03, total=1.5313e-02, data=4.1388e-06, sparsity_reg=1.5308e-02, imag_w=8.8915e-07, active_edges=106
# [PHASE1 | Epoch 17900] lr=1.00e-03, total=1.5241e-02, data=3.6002e-06, sparsity_reg=1.5237e-02, imag_w=7.9043e-07, active_edges=106
# [PHASE1 | Epoch 18000] lr=1.00e-03, total=1.5173e-02, data=1.0399e-06, sparsity_reg=1.5171e-02, imag_w=1.2550e-06, active_edges=106
# [PHASE1 | Epoch 18100] lr=1.00e-03, total=1.5117e-02, data=9.9250e-07, sparsity_reg=1.5115e-02, imag_w=9.4517e-07, active_edges=106
# [PHASE1 | Epoch 18200] lr=1.00e-03, total=1.5060e-02, data=8.1351e-07, sparsity_reg=1.5059e-02, imag_w=8.4748e-07, active_edges=106
# [PHASE1 | Epoch 18300] lr=1.00e-03, total=1.5005e-02, data=1.4870e-06, sparsity_reg=1.5003e-02, imag_w=1.0150e-06, active_edges=106
# [PHASE1 | Epoch 18400] lr=1.00e-03, total=1.4958e-02, data=1.1909e-06, sparsity_reg=1.4956e-02, imag_w=8.6800e-07, active_edges=106
# [PHASE1 | Epoch 18500] lr=1.00e-03, total=1.5002e-02, data=9.1880e-05, sparsity_reg=1.4910e-02, imag_w=8.6072e-07, active_edges=106
# [PHASE1 | Epoch 18600] lr=1.00e-03, total=1.4863e-02, data=5.8781e-07, sparsity_reg=1.4862e-02, imag_w=9.2886e-07, active_edges=106
# [PHASE1 | Epoch 18700] lr=1.00e-03, total=1.4815e-02, data=8.7353e-07, sparsity_reg=1.4814e-02, imag_w=7.9471e-07, active_edges=106
# [PHASE1 | Epoch 18800] lr=1.00e-03, total=1.4770e-02, data=3.0263e-06, sparsity_reg=1.4765e-02, imag_w=1.3702e-06, active_edges=106
# [PHASE1 | Epoch 18900] lr=1.00e-03, total=1.4719e-02, data=3.6255e-06, sparsity_reg=1.4715e-02, imag_w=8.5092e-07, active_edges=106
# [PHASE1 | Epoch 19000] lr=1.00e-03, total=1.4667e-02, data=2.7653e-06, sparsity_reg=1.4664e-02, imag_w=7.1033e-07, active_edges=106
# [PHASE1 | Epoch 19100] lr=1.00e-03, total=1.4627e-02, data=1.2063e-06, sparsity_reg=1.4624e-02, imag_w=1.8905e-06, active_edges=106
# [PHASE1 | Epoch 19200] lr=1.00e-03, total=1.4589e-02, data=1.3165e-06, sparsity_reg=1.4587e-02, imag_w=1.0271e-06, active_edges=106
# [PHASE1 | Epoch 19300] lr=1.00e-03, total=1.4563e-02, data=1.1820e-05, sparsity_reg=1.4551e-02, imag_w=6.2987e-07, active_edges=106
# [PHASE1 | Epoch 19400] lr=1.00e-03, total=1.4522e-02, data=8.0670e-06, sparsity_reg=1.4513e-02, imag_w=6.6693e-07, active_edges=106
# [PHASE1 | Epoch 19500] lr=1.00e-03, total=1.4476e-02, data=7.6511e-07, sparsity_reg=1.4475e-02, imag_w=6.1244e-07, active_edges=106
# [PHASE1 | Epoch 19600] lr=1.00e-03, total=1.4439e-02, data=2.6881e-06, sparsity_reg=1.4435e-02, imag_w=6.0418e-07, active_edges=106
# [PHASE1 | Epoch 19700] lr=1.00e-03, total=1.4398e-02, data=1.2171e-06, sparsity_reg=1.4396e-02, imag_w=7.3364e-07, active_edges=106
# [PHASE1 | Epoch 19800] lr=1.00e-03, total=1.4358e-02, data=3.3384e-06, sparsity_reg=1.4354e-02, imag_w=6.5322e-07, active_edges=106
# [PHASE1 | Epoch 19900] lr=1.00e-03, total=1.4361e-02, data=4.9416e-05, sparsity_reg=1.4311e-02, imag_w=5.7755e-07, active_edges=106
# [PHASE1 | Epoch 20000] lr=1.00e-03, total=1.4364e-02, data=9.6246e-05, sparsity_reg=1.4267e-02, imag_w=5.8816e-07, active_edges=106
# [PHASE1_END] thr=0.1 pruned=83 cleaned=0 active 106->23 (pre_rebuild=23)
# [PHASE2 | Epoch 20100] lr=1.00e-03, total=1.4212e-02, data=4.6237e-07, sparsity_reg=1.4211e-02, imag_w=2.4938e-11, active_edges=23
# [PHASE2 | Epoch 20200] lr=1.00e-03, total=1.4169e-02, data=4.4199e-07, sparsity_reg=1.4168e-02, imag_w=1.3521e-16, active_edges=23
# [PHASE2 | Epoch 20300] lr=1.00e-03, total=1.4111e-02, data=4.4198e-07, sparsity_reg=1.4111e-02, imag_w=6.8857e-20, active_edges=23
# [PHASE2 | Epoch 20400] lr=1.00e-03, total=1.4040e-02, data=4.3915e-07, sparsity_reg=1.4040e-02, imag_w=2.3418e-24, active_edges=23
# [PHASE2 | Epoch 20500] lr=1.00e-03, total=1.3957e-02, data=4.3667e-07, sparsity_reg=1.3957e-02, imag_w=1.8859e-29, active_edges=23
# [PHASE2 | Epoch 20600] lr=1.00e-03, total=1.3862e-02, data=4.3329e-07, sparsity_reg=1.3862e-02, imag_w=3.6459e-33, active_edges=23
# [PHASE2 | Epoch 20700] lr=1.00e-03, total=1.3757e-02, data=1.1190e-06, sparsity_reg=1.3756e-02, imag_w=4.3008e-38, active_edges=23
# [PHASE2 | Epoch 20800] lr=1.00e-03, total=1.3641e-02, data=4.2328e-07, sparsity_reg=1.3641e-02, imag_w=1.2612e-42, active_edges=23
# [PHASE2 | Epoch 20900] lr=1.00e-03, total=1.3636e-02, data=3.3689e-05, sparsity_reg=1.3598e-02, imag_w=4.2056e-06, active_edges=23
# [PHASE2 | Epoch 21000] lr=1.00e-03, total=1.3588e-02, data=4.1617e-07, sparsity_reg=1.3587e-02, imag_w=4.4401e-10, active_edges=23
# [PHASE2 | Epoch 21100] lr=1.00e-03, total=1.3578e-02, data=1.4974e-06, sparsity_reg=1.3577e-02, imag_w=1.4120e-11, active_edges=23
# [PHASE2 | Epoch 21200] lr=1.00e-03, total=1.3566e-02, data=4.0869e-07, sparsity_reg=1.3566e-02, imag_w=8.9962e-16, active_edges=23
# [PHASE2 | Epoch 21300] lr=1.00e-03, total=1.3564e-02, data=9.2062e-06, sparsity_reg=1.3555e-02, imag_w=1.3110e-09, active_edges=23
# [PHASE2 | Epoch 21400] lr=1.00e-03, total=1.3544e-02, data=3.9739e-07, sparsity_reg=1.3544e-02, imag_w=7.9362e-12, active_edges=23
# [PHASE2 | Epoch 21500] lr=1.00e-03, total=1.3533e-02, data=4.0029e-07, sparsity_reg=1.3532e-02, imag_w=4.9444e-18, active_edges=23
# [PHASE2 | Epoch 21600] lr=1.00e-03, total=1.3521e-02, data=6.6018e-07, sparsity_reg=1.3521e-02, imag_w=7.8775e-21, active_edges=23
# [PHASE2 | Epoch 21700] lr=1.00e-03, total=1.3509e-02, data=3.9199e-07, sparsity_reg=1.3509e-02, imag_w=1.9078e-25, active_edges=23
# [PHASE2 | Epoch 21800] lr=1.00e-03, total=1.3499e-02, data=2.1486e-06, sparsity_reg=1.3497e-02, imag_w=3.0926e-30, active_edges=23
# [PHASE2 | Epoch 21900] lr=1.00e-03, total=1.3485e-02, data=3.8323e-07, sparsity_reg=1.3485e-02, imag_w=2.2225e-34, active_edges=23
# [PHASE2 | Epoch 22000] lr=1.00e-03, total=1.3479e-02, data=6.7502e-06, sparsity_reg=1.3472e-02, imag_w=1.0644e-38, active_edges=23
# [PHASE2 | Epoch 22100] lr=1.00e-03, total=1.3460e-02, data=3.8483e-07, sparsity_reg=1.3460e-02, imag_w=4.7422e-37, active_edges=23
# [PHASE2 | Epoch 22200] lr=1.00e-03, total=1.3454e-02, data=6.8616e-06, sparsity_reg=1.3447e-02, imag_w=2.5361e-10, active_edges=23
# [PHASE2 | Epoch 22300] lr=1.00e-03, total=1.3435e-02, data=3.7103e-07, sparsity_reg=1.3435e-02, imag_w=4.0383e-12, active_edges=23
# [PHASE2 | Epoch 22400] lr=1.00e-03, total=1.3425e-02, data=2.9301e-06, sparsity_reg=1.3422e-02, imag_w=4.2918e-19, active_edges=23
# [PHASE2 | Epoch 22500] lr=1.00e-03, total=1.3409e-02, data=3.6825e-07, sparsity_reg=1.3409e-02, imag_w=1.0101e-20, active_edges=23
# [PHASE2 | Epoch 22600] lr=1.00e-03, total=1.3405e-02, data=9.5725e-06, sparsity_reg=1.3396e-02, imag_w=1.4939e-25, active_edges=23
# [PHASE2 | Epoch 22700] lr=1.00e-03, total=1.3383e-02, data=3.6185e-07, sparsity_reg=1.3382e-02, imag_w=8.2869e-30, active_edges=23
# [PHASE2 | Epoch 22800] lr=1.00e-03, total=1.3370e-02, data=1.5181e-06, sparsity_reg=1.3369e-02, imag_w=1.0154e-34, active_edges=23
# [PHASE2 | Epoch 22900] lr=1.00e-03, total=1.3356e-02, data=3.5785e-07, sparsity_reg=1.3356e-02, imag_w=1.8403e-16, active_edges=23
# [PHASE2 | Epoch 23000] lr=1.00e-03, total=1.3353e-02, data=1.1047e-05, sparsity_reg=1.3342e-02, imag_w=2.3725e-11, active_edges=23
# [PHASE2 | Epoch 23100] lr=1.00e-03, total=1.3329e-02, data=3.5360e-07, sparsity_reg=1.3329e-02, imag_w=2.1159e-15, active_edges=23
# [PHASE2 | Epoch 23200] lr=1.00e-03, total=1.3328e-02, data=1.2942e-05, sparsity_reg=1.3315e-02, imag_w=1.8760e-20, active_edges=23
# [PHASE2 | Epoch 23300] lr=1.00e-03, total=1.3328e-02, data=2.5866e-05, sparsity_reg=1.3302e-02, imag_w=1.2394e-23, active_edges=23
# [PHASE2 | Epoch 23400] lr=1.00e-03, total=1.3288e-02, data=3.5889e-07, sparsity_reg=1.3288e-02, imag_w=4.2718e-28, active_edges=23
# [PHASE2 | Epoch 23500] lr=1.00e-03, total=1.3275e-02, data=9.6672e-07, sparsity_reg=1.3274e-02, imag_w=1.9518e-08, active_edges=23
# [PHASE2 | Epoch 23600] lr=1.00e-03, total=1.3279e-02, data=1.9480e-05, sparsity_reg=1.3259e-02, imag_w=2.0359e-08, active_edges=23
# [PHASE2 | Epoch 23700] lr=1.00e-03, total=1.3246e-02, data=3.5510e-07, sparsity_reg=1.3245e-02, imag_w=1.3914e-08, active_edges=23
# [PHASE2 | Epoch 23800] lr=1.00e-03, total=1.3240e-02, data=8.9604e-06, sparsity_reg=1.3231e-02, imag_w=1.1965e-08, active_edges=23
# [PHASE2 | Epoch 23900] lr=1.00e-03, total=1.3217e-02, data=3.4489e-07, sparsity_reg=1.3217e-02, imag_w=1.3021e-08, active_edges=23
# [PHASE2 | Epoch 24000] lr=1.00e-03, total=1.3211e-02, data=9.3478e-06, sparsity_reg=1.3202e-02, imag_w=3.9033e-08, active_edges=23
# [PHASE2 | Epoch 24100] lr=1.00e-03, total=1.3190e-02, data=2.4960e-06, sparsity_reg=1.3188e-02, imag_w=2.7714e-08, active_edges=23
# [PHASE2 | Epoch 24200] lr=1.00e-03, total=1.3195e-02, data=2.3043e-05, sparsity_reg=1.3172e-02, imag_w=4.9509e-08, active_edges=23
# [PHASE2 | Epoch 24300] lr=1.00e-03, total=1.3158e-02, data=3.3996e-07, sparsity_reg=1.3158e-02, imag_w=4.2554e-08, active_edges=23
# [PHASE2 | Epoch 24400] lr=1.00e-03, total=1.3144e-02, data=4.4679e-07, sparsity_reg=1.3143e-02, imag_w=2.9936e-08, active_edges=23
# [PHASE2 | Epoch 24500] lr=1.00e-03, total=1.3130e-02, data=1.8311e-06, sparsity_reg=1.3128e-02, imag_w=2.7097e-08, active_edges=23
# [PHASE2 | Epoch 24600] lr=1.00e-03, total=1.3114e-02, data=9.5033e-07, sparsity_reg=1.3113e-02, imag_w=1.9724e-08, active_edges=23
# [PHASE2 | Epoch 24700] lr=1.00e-03, total=1.3099e-02, data=3.3558e-07, sparsity_reg=1.3098e-02, imag_w=4.2391e-07, active_edges=23
# [PHASE2 | Epoch 24800] lr=1.00e-03, total=1.3084e-02, data=8.2707e-07, sparsity_reg=1.3083e-02, imag_w=2.0102e-08, active_edges=23
# [PHASE2 | Epoch 24900] lr=1.00e-03, total=1.3069e-02, data=1.3184e-06, sparsity_reg=1.3068e-02, imag_w=8.1608e-09, active_edges=23
# [PHASE2 | Epoch 25000] lr=1.00e-03, total=1.3052e-02, data=3.9084e-07, sparsity_reg=1.3052e-02, imag_w=8.0615e-09, active_edges=23
# [PRUNE_SYM | PHASE2_E5000 | layer=1] pruned=2 (fraction=0.3, thr=0.1) active 13->11
# [CLEAN | PHASE2_E5000] cleaned_disconnected=2
# [PRUNE | PHASE2_E5000] pruned_total=2 active 23->19
# [PHASE2 | Epoch 25100] lr=1.00e-03, total=1.2995e-02, data=1.7160e-06, sparsity_reg=1.2993e-02, imag_w=2.0036e-10, active_edges=19
# [PHASE2 | Epoch 25200] lr=1.00e-03, total=1.2985e-02, data=3.6863e-07, sparsity_reg=1.2985e-02, imag_w=2.0631e-15, active_edges=19
# [PHASE2 | Epoch 25300] lr=1.00e-03, total=1.2974e-02, data=3.7223e-07, sparsity_reg=1.2974e-02, imag_w=8.2333e-20, active_edges=19
# [PHASE2 | Epoch 25400] lr=1.00e-03, total=1.2963e-02, data=3.6310e-07, sparsity_reg=1.2963e-02, imag_w=6.7571e-24, active_edges=19
# [PHASE2 | Epoch 25500] lr=1.00e-03, total=1.2951e-02, data=5.1909e-07, sparsity_reg=1.2951e-02, imag_w=1.8579e-28, active_edges=19
# [PHASE2 | Epoch 25600] lr=1.00e-03, total=1.2938e-02, data=3.3456e-07, sparsity_reg=1.2938e-02, imag_w=3.1299e-33, active_edges=19
# [PHASE2 | Epoch 25700] lr=1.00e-03, total=1.2926e-02, data=3.5129e-07, sparsity_reg=1.2926e-02, imag_w=1.6071e-37, active_edges=19
# [PHASE2 | Epoch 25800] lr=1.00e-03, total=1.2913e-02, data=3.3198e-07, sparsity_reg=1.2913e-02, imag_w=1.4013e-44, active_edges=19
# [PHASE2 | Epoch 25900] lr=1.00e-03, total=1.2900e-02, data=3.7362e-07, sparsity_reg=1.2899e-02, imag_w=0.0000e+00, active_edges=19
# [PHASE2 | Epoch 26000] lr=1.00e-03, total=1.2886e-02, data=3.1875e-07, sparsity_reg=1.2885e-02, imag_w=0.0000e+00, active_edges=19
# [PHASE2 | Epoch 26100] lr=1.00e-03, total=1.2872e-02, data=3.3792e-07, sparsity_reg=1.2871e-02, imag_w=0.0000e+00, active_edges=19
# [PHASE2 | Epoch 26200] lr=1.00e-03, total=1.2857e-02, data=3.6996e-07, sparsity_reg=1.2857e-02, imag_w=0.0000e+00, active_edges=19
# [PHASE2 | Epoch 26300] lr=1.00e-03, total=1.2842e-02, data=3.2790e-07, sparsity_reg=1.2842e-02, imag_w=0.0000e+00, active_edges=19
# [PHASE2 | Epoch 26400] lr=1.00e-03, total=1.2827e-02, data=4.8552e-07, sparsity_reg=1.2826e-02, imag_w=0.0000e+00, active_edges=19
# [PHASE2 | Epoch 26500] lr=1.00e-03, total=1.2811e-02, data=3.2622e-07, sparsity_reg=1.2811e-02, imag_w=0.0000e+00, active_edges=19
# [PHASE2 | Epoch 26600] lr=1.00e-03, total=1.2794e-02, data=3.2817e-07, sparsity_reg=1.2794e-02, imag_w=1.3228e-41, active_edges=19
# [PHASE2 | Epoch 26700] lr=1.00e-03, total=1.2778e-02, data=1.1588e-06, sparsity_reg=1.2777e-02, imag_w=6.9610e-08, active_edges=19
# [PHASE2 | Epoch 26800] lr=1.00e-03, total=1.2761e-02, data=2.9823e-07, sparsity_reg=1.2761e-02, imag_w=7.1602e-13, active_edges=19
# [PHASE2 | Epoch 26900] lr=1.00e-03, total=1.2745e-02, data=4.4835e-07, sparsity_reg=1.2745e-02, imag_w=6.7703e-17, active_edges=19
# [PHASE2 | Epoch 27000] lr=1.00e-03, total=1.2729e-02, data=3.9850e-07, sparsity_reg=1.2729e-02, imag_w=1.9528e-21, active_edges=19
# [PHASE2 | Epoch 27100] lr=1.00e-03, total=1.2712e-02, data=3.1568e-07, sparsity_reg=1.2712e-02, imag_w=5.8017e-26, active_edges=19
# [PHASE2 | Epoch 27200] lr=1.00e-03, total=1.2694e-02, data=3.6167e-07, sparsity_reg=1.2694e-02, imag_w=6.3671e-31, active_edges=19
# [PHASE2 | Epoch 27300] lr=1.00e-03, total=1.2676e-02, data=5.5906e-07, sparsity_reg=1.2675e-02, imag_w=3.1216e-35, active_edges=19
# [PHASE2 | Epoch 27400] lr=1.00e-03, total=1.2657e-02, data=7.8798e-07, sparsity_reg=1.2656e-02, imag_w=1.9548e-41, active_edges=19
# [PHASE2 | Epoch 27500] lr=1.00e-03, total=1.2664e-02, data=2.7170e-05, sparsity_reg=1.2637e-02, imag_w=7.0065e-44, active_edges=19
# [PHASE2 | Epoch 27600] lr=1.00e-03, total=1.2630e-02, data=1.2984e-05, sparsity_reg=1.2617e-02, imag_w=0.0000e+00, active_edges=19
# [PHASE2 | Epoch 27700] lr=1.00e-03, total=1.2615e-02, data=1.6910e-05, sparsity_reg=1.2598e-02, imag_w=8.6396e-24, active_edges=19
# [PHASE2 | Epoch 27800] lr=1.00e-03, total=1.2578e-02, data=4.4905e-07, sparsity_reg=1.2577e-02, imag_w=2.2638e-09, active_edges=19
# [PHASE2 | Epoch 27900] lr=1.00e-03, total=1.2558e-02, data=3.4260e-07, sparsity_reg=1.2557e-02, imag_w=6.5082e-14, active_edges=19
# [PHASE2 | Epoch 28000] lr=1.00e-03, total=1.2538e-02, data=4.0965e-07, sparsity_reg=1.2537e-02, imag_w=1.1910e-18, active_edges=19
# [PHASE2 | Epoch 28100] lr=1.00e-03, total=1.2518e-02, data=1.3968e-06, sparsity_reg=1.2517e-02, imag_w=9.8957e-24, active_edges=19
# [PHASE2 | Epoch 28200] lr=1.00e-03, total=1.2497e-02, data=9.2196e-07, sparsity_reg=1.2496e-02, imag_w=1.1165e-27, active_edges=19
# [PHASE2 | Epoch 28300] lr=1.00e-03, total=1.2476e-02, data=4.7979e-07, sparsity_reg=1.2475e-02, imag_w=9.9048e-33, active_edges=19
# [PHASE2 | Epoch 28400] lr=1.00e-03, total=1.2455e-02, data=3.6054e-07, sparsity_reg=1.2455e-02, imag_w=3.3405e-36, active_edges=19
# [PHASE2 | Epoch 28500] lr=1.00e-03, total=1.2587e-02, data=1.5497e-04, sparsity_reg=1.2432e-02, imag_w=4.9596e-32, active_edges=19
# [PHASE2 | Epoch 28600] lr=1.00e-03, total=1.2413e-02, data=3.3107e-07, sparsity_reg=1.2413e-02, imag_w=5.9967e-09, active_edges=19
# [PHASE2 | Epoch 28700] lr=1.00e-03, total=1.2399e-02, data=1.3804e-06, sparsity_reg=1.2394e-02, imag_w=3.3440e-06, active_edges=19
# [PHASE2 | Epoch 28800] lr=1.00e-03, total=1.2381e-02, data=3.2574e-07, sparsity_reg=1.2380e-02, imag_w=6.7543e-10, active_edges=19
# [PHASE2 | Epoch 28900] lr=1.00e-03, total=1.2368e-02, data=7.3830e-07, sparsity_reg=1.2367e-02, imag_w=9.6927e-11, active_edges=19
# [PHASE2 | Epoch 29000] lr=1.00e-03, total=1.2363e-02, data=9.1058e-06, sparsity_reg=1.2354e-02, imag_w=3.3049e-10, active_edges=19
# [PHASE2 | Epoch 29100] lr=1.00e-03, total=1.2423e-02, data=8.1279e-05, sparsity_reg=1.2342e-02, imag_w=1.7405e-09, active_edges=19
# [PHASE2 | Epoch 29200] lr=1.00e-03, total=1.2328e-02, data=6.0156e-07, sparsity_reg=1.2327e-02, imag_w=7.2759e-12, active_edges=19
# [PHASE2 | Epoch 29300] lr=1.00e-03, total=1.2315e-02, data=3.7268e-07, sparsity_reg=1.2314e-02, imag_w=6.1999e-08, active_edges=19
# [PHASE2 | Epoch 29400] lr=1.00e-03, total=1.2301e-02, data=3.3569e-07, sparsity_reg=1.2301e-02, imag_w=2.4080e-12, active_edges=19
# [PHASE2 | Epoch 29500] lr=1.00e-03, total=1.2288e-02, data=3.5519e-07, sparsity_reg=1.2288e-02, imag_w=8.1836e-09, active_edges=19
# [PHASE2 | Epoch 29600] lr=1.00e-03, total=1.2275e-02, data=2.9647e-07, sparsity_reg=1.2275e-02, imag_w=7.2569e-10, active_edges=19
# [PHASE2 | Epoch 29700] lr=1.00e-03, total=1.2263e-02, data=1.4607e-06, sparsity_reg=1.2262e-02, imag_w=1.9095e-08, active_edges=19
# [PHASE2 | Epoch 29800] lr=1.00e-03, total=1.2249e-02, data=4.9671e-07, sparsity_reg=1.2248e-02, imag_w=4.0670e-09, active_edges=19
# [PHASE2 | Epoch 29900] lr=1.00e-03, total=1.2237e-02, data=1.1984e-06, sparsity_reg=1.2235e-02, imag_w=3.7406e-07, active_edges=19
# [PHASE2 | Epoch 30000] lr=1.00e-03, total=1.2222e-02, data=4.2294e-07, sparsity_reg=1.2222e-02, imag_w=1.9592e-09, active_edges=19
# [PRUNE_SYM | PHASE2_E10000 | layer=1] pruned=2 (fraction=0.3, thr=0.1) active 11->9
# [PRUNE | PHASE2_E10000] pruned_total=2 active 19->17
# [PHASE2 | Epoch 30100] lr=1.00e-03, total=1.2165e-02, data=1.1712e-05, sparsity_reg=1.2153e-02, imag_w=2.3442e-10, active_edges=17
# [PHASE2 | Epoch 30200] lr=1.00e-03, total=1.2151e-02, data=1.8557e-07, sparsity_reg=1.2151e-02, imag_w=1.0993e-14, active_edges=17
# [PHASE2 | Epoch 30300] lr=1.00e-03, total=1.2148e-02, data=1.9167e-07, sparsity_reg=1.2148e-02, imag_w=3.5212e-20, active_edges=17
# [PHASE2 | Epoch 30400] lr=1.00e-03, total=1.2145e-02, data=1.9817e-07, sparsity_reg=1.2144e-02, imag_w=2.1532e-24, active_edges=17
# [PHASE2 | Epoch 30500] lr=1.00e-03, total=1.2141e-02, data=1.9325e-07, sparsity_reg=1.2140e-02, imag_w=1.4805e-28, active_edges=17
# [PHASE2 | Epoch 30600] lr=1.00e-03, total=1.2136e-02, data=1.9229e-07, sparsity_reg=1.2136e-02, imag_w=2.0312e-33, active_edges=17
# [PHASE2 | Epoch 30700] lr=1.00e-03, total=1.2131e-02, data=1.8045e-07, sparsity_reg=1.2131e-02, imag_w=1.1970e-37, active_edges=17
# [PHASE2 | Epoch 30800] lr=1.00e-03, total=1.2125e-02, data=1.8681e-07, sparsity_reg=1.2125e-02, imag_w=5.6052e-44, active_edges=17
# [PHASE2 | Epoch 30900] lr=1.00e-03, total=1.2119e-02, data=2.0034e-07, sparsity_reg=1.2119e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31000] lr=1.00e-03, total=1.2112e-02, data=2.1911e-07, sparsity_reg=1.2112e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31100] lr=1.00e-03, total=1.2105e-02, data=1.7866e-07, sparsity_reg=1.2105e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31200] lr=1.00e-03, total=1.2097e-02, data=1.8354e-07, sparsity_reg=1.2097e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31300] lr=1.00e-03, total=1.2089e-02, data=1.9826e-07, sparsity_reg=1.2088e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31400] lr=1.00e-03, total=1.2080e-02, data=2.9557e-07, sparsity_reg=1.2080e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31500] lr=1.00e-03, total=1.2074e-02, data=3.3669e-06, sparsity_reg=1.2071e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31600] lr=1.00e-03, total=1.2062e-02, data=2.6449e-07, sparsity_reg=1.2061e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31700] lr=1.00e-03, total=1.2052e-02, data=2.1783e-07, sparsity_reg=1.2052e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31800] lr=1.00e-03, total=1.2043e-02, data=2.3211e-07, sparsity_reg=1.2042e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 31900] lr=1.00e-03, total=1.2033e-02, data=5.4775e-07, sparsity_reg=1.2032e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 32000] lr=1.00e-03, total=1.2036e-02, data=1.3355e-05, sparsity_reg=1.2023e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 32100] lr=1.00e-03, total=1.2013e-02, data=3.1859e-07, sparsity_reg=1.2012e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 32200] lr=1.00e-03, total=1.2002e-02, data=3.9234e-07, sparsity_reg=1.2002e-02, imag_w=4.1723e-08, active_edges=17
# [PHASE2 | Epoch 32300] lr=1.00e-03, total=1.1992e-02, data=4.4479e-07, sparsity_reg=1.1991e-02, imag_w=4.8342e-12, active_edges=17
# [PHASE2 | Epoch 32400] lr=1.00e-03, total=1.1981e-02, data=2.8160e-07, sparsity_reg=1.1981e-02, imag_w=5.5941e-17, active_edges=17
# [PHASE2 | Epoch 32500] lr=1.00e-03, total=1.1977e-02, data=7.3494e-06, sparsity_reg=1.1970e-02, imag_w=3.2429e-21, active_edges=17
# [PHASE2 | Epoch 32600] lr=1.00e-03, total=1.1959e-02, data=2.4633e-07, sparsity_reg=1.1959e-02, imag_w=2.7213e-26, active_edges=17
# [PHASE2 | Epoch 32700] lr=1.00e-03, total=1.1948e-02, data=5.7000e-07, sparsity_reg=1.1948e-02, imag_w=2.4323e-31, active_edges=17
# [PHASE2 | Epoch 32800] lr=1.00e-03, total=1.1938e-02, data=2.2951e-06, sparsity_reg=1.1936e-02, imag_w=1.4324e-36, active_edges=17
# [PHASE2 | Epoch 32900] lr=1.00e-03, total=1.1925e-02, data=3.0075e-07, sparsity_reg=1.1925e-02, imag_w=1.5943e-39, active_edges=17
# [PHASE2 | Epoch 33000] lr=1.00e-03, total=1.1914e-02, data=4.0620e-07, sparsity_reg=1.1913e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 33100] lr=1.00e-03, total=1.1902e-02, data=4.1264e-07, sparsity_reg=1.1902e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 33200] lr=1.00e-03, total=1.1890e-02, data=3.1117e-07, sparsity_reg=1.1890e-02, imag_w=0.0000e+00, active_edges=17
# [PHASE2 | Epoch 33300] lr=1.00e-03, total=1.1880e-02, data=2.2172e-06, sparsity_reg=1.1878e-02, imag_w=1.5702e-12, active_edges=17
# [PHASE2 | Epoch 33400] lr=1.00e-03, total=1.1867e-02, data=2.6676e-07, sparsity_reg=1.1866e-02, imag_w=2.6662e-11, active_edges=17
# [PHASE2 | Epoch 33500] lr=1.00e-03, total=1.1855e-02, data=3.9056e-07, sparsity_reg=1.1855e-02, imag_w=1.9299e-15, active_edges=17
# [PHASE2 | Epoch 33600] lr=1.00e-03, total=1.1846e-02, data=2.8296e-06, sparsity_reg=1.1843e-02, imag_w=8.3717e-20, active_edges=17
# [PHASE2 | Epoch 33700] lr=1.00e-03, total=1.1831e-02, data=4.4351e-07, sparsity_reg=1.1831e-02, imag_w=1.0300e-24, active_edges=17
# [PHASE2 | Epoch 33800] lr=1.00e-03, total=1.1823e-02, data=4.2921e-06, sparsity_reg=1.1819e-02, imag_w=4.4349e-32, active_edges=17
# [PHASE2 | Epoch 33900] lr=1.00e-03, total=1.1808e-02, data=2.6807e-07, sparsity_reg=1.1807e-02, imag_w=1.7864e-33, active_edges=17
# [PHASE2 | Epoch 34000] lr=1.00e-03, total=1.1808e-02, data=1.1520e-05, sparsity_reg=1.1796e-02, imag_w=5.7831e-09, active_edges=17
# [PHASE2 | Epoch 34100] lr=1.00e-03, total=1.1786e-02, data=2.6884e-07, sparsity_reg=1.1786e-02, imag_w=4.8681e-09, active_edges=17
# [PHASE2 | Epoch 34200] lr=1.00e-03, total=1.1775e-02, data=3.7973e-07, sparsity_reg=1.1775e-02, imag_w=2.2706e-10, active_edges=17
# [PHASE2 | Epoch 34300] lr=1.00e-03, total=1.1767e-02, data=3.5246e-06, sparsity_reg=1.1764e-02, imag_w=5.1872e-09, active_edges=17
# [PHASE2 | Epoch 34400] lr=1.00e-03, total=1.1756e-02, data=3.4115e-06, sparsity_reg=1.1753e-02, imag_w=2.0001e-08, active_edges=17
# [PHASE2 | Epoch 34500] lr=1.00e-03, total=1.1745e-02, data=2.8215e-06, sparsity_reg=1.1742e-02, imag_w=2.0712e-08, active_edges=17
# [PHASE2 | Epoch 34600] lr=1.00e-03, total=1.1731e-02, data=5.3428e-07, sparsity_reg=1.1731e-02, imag_w=1.3900e-08, active_edges=17
# [PHASE2 | Epoch 34700] lr=1.00e-03, total=1.1720e-02, data=3.1545e-07, sparsity_reg=1.1719e-02, imag_w=1.2216e-08, active_edges=17
# [PHASE2 | Epoch 34800] lr=1.00e-03, total=1.1709e-02, data=3.9829e-07, sparsity_reg=1.1708e-02, imag_w=1.2145e-08, active_edges=17
-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 67200] lr=1.00e-06, total=7.4879e-12, data=7.4879e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 67300] lr=1.00e-06, total=7.4104e-12, data=7.4104e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 67400] lr=1.00e-06, total=8.3545e-12, data=8.3545e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 67500] lr=1.00e-06, total=6.3914e-12, data=6.3914e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 67600] lr=1.00e-06, total=1.4116e-11, data=1.4116e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 67700] lr=1.00e-06, total=6.2600e-12, data=6.2600e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 67800] lr=1.00e-06, total=8.1744e-12, data=8.1744e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 67900] lr=1.00e-06, total=5.2480e-11, data=5.2480e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68000] lr=1.00e-06, total=7.1291e-12, data=7.1291e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68100] lr=1.00e-06, total=1.0517e-11, data=1.0517e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68200] lr=1.00e-06, total=1.6698e-11, data=1.6698e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68300] lr=1.00e-06, total=1.1167e-11, data=1.1167e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68400] lr=1.00e-06, total=1.9891e-11, data=1.9891e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68500] lr=1.00e-06, total=2.0044e-11, data=2.0044e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68600] lr=1.00e-06, total=1.3837e-11, data=1.3837e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68700] lr=1.00e-06, total=7.6452e-12, data=7.6452e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68800] lr=1.00e-06, total=1.1238e-11, data=1.1238e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 68900] lr=1.00e-06, total=1.9613e-11, data=1.9613e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69000] lr=1.00e-06, total=1.5731e-11, data=1.5731e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69100] lr=1.00e-06, total=5.6034e-11, data=5.6034e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69200] lr=1.00e-06, total=1.8401e-10, data=1.8401e-10, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69300] lr=1.00e-06, total=1.2473e-11, data=1.2473e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69400] lr=1.00e-06, total=8.3945e-12, data=8.3945e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69500] lr=1.00e-06, total=1.4302e-11, data=1.4302e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69600] lr=1.00e-06, total=7.1487e-12, data=7.1487e-12, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69700] lr=1.00e-06, total=1.3565e-11, data=1.3565e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69800] lr=1.00e-06, total=1.0209e-11, data=1.0209e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 69900] lr=1.00e-06, total=1.8825e-11, data=1.8825e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# [PHASE3 | Epoch 70000] lr=1.00e-06, total=1.4117e-11, data=1.4117e-11, sparsity_reg=0.0000e+00, imag_w=0.0000e+00, active_edges=15
# train() finished
# expr_str: 1.59999991578886*X1**2 + 0.509999969234584*X1*X2 - 0.519999955909862*X1 + 1.03999993422789*X2**2 + 2.63999997955892*X2 - 2.95000000597704
# RESULT | Expression=P2 | d= 64 | run=5/5 | seed=4 | train_mse=6.825160e-12 | test_mse=2.493907e-10
# Saved per-run report: reports/ceql_scalability_poly2.csv
#
# === Summary (mean±std over runs) ===
# Expression=P2 d=  2 | train_mse=3.086914e-11±3.803549e-11 | test_mse=1.203374e-09±1.501099e-09
# Expression=P2 d=  4 | train_mse=4.118423e-11±3.873310e-11 | test_mse=1.493015e-09±1.441707e-09
# Expression=P2 d=  8 | train_mse=2.435188e-04±4.870376e-04 | test_mse=1.666096e-01±3.332192e-01
# Expression=P2 d= 16 | train_mse=1.978599e-06±3.957151e-06 | test_mse=4.117303e-03±8.234605e-03
# Expression=P2 d= 32 | train_mse=3.139646e-11±3.293674e-11 | test_mse=1.524907e-09±1.323868e-09
# Expression=P2 d= 64 | train_mse=6.413159e-12±5.194532e-13 | test_mse=2.192392e-10±2.557078e-11
# All done in 7234.07 s
